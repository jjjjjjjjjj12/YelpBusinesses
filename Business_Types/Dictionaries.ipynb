# %%
## Function to map titles to macrocategories if not in top 150

def map_category(category):
    if category not in top_150:
        if category in dict_2B.keys():
            title = dict_2B[category]
        else:
            title = category
        if title in dict_2A.keys():
            title_2 = dict_2A[title]
            return(title_2)
        else:
            return(title)
    else:
        return(category)

# %%
## Example of how to apply the mapping function

cat['title_3'] = cat['country_blacklist']
for index, cell in enumerate(cat['title']):
    cat['title_3'][index] = map_category(cat['title'][index])

# %%
dict_2A = {'active': 'Active Life',
 'diving': 'Active Life',
 'fitness': 'Active Life',
 'gyms': 'Active Life',
 'martialarts': 'Active Life',
 'othersalons': 'Active Life',
 'parks': 'Active Life',
 'zoos': 'Active Life',
 'arts': 'Arts & Entertainment',
 'farms': 'Arts & Entertainment',
 'festivals': 'Arts & Entertainment',
 'movietheaters': 'Arts & Entertainment',
 'museums': 'Arts & Entertainment',
 'psychic_astrology': 'Arts & Entertainment',
 'social_clubs': 'Arts & Entertainment',
 'wineries': 'Arts & Entertainment',
 'auto': 'Automotive',
 'autoglass': 'Automotive',
 'autopartssupplies': 'Automotive',
 'autorepair': 'Automotive',
 'beautysvc': 'Beauty & Spas',
 'hair': 'Beauty & Spas',
 'hairremoval': 'Beauty & Spas',
 'medicalspa': 'Beauty & Spas',
 'skincare': 'Beauty & Spas',
 'tanning': 'Beauty & Spas',
 'bicycles': 'Bicycles',
 'artclasses': 'Education',
 'education': 'Education',
 'specialtyschools': 'Education',
 'tastingclasses': 'Education',
 'eventservices': 'Event Planning & Services',
 'partyequipmentrentals': 'Event Planning & Services',
 'photographers': 'Event Planning & Services',
 'financialservices': 'Financial Services',
 'insurance': 'Financial Services',
 'breweries': 'Food',
 'food': 'Food',
 'gourmet': 'Food',
 'jpsweets': 'Food',
 'c_and_mh': 'Health & Medical',
 'cannabis_clinics': 'Health & Medical',
 'crisispregnancycenters': 'Health & Medical',
 'dentalhygienists': 'Health & Medical',
 'diagnosticservices': 'Health & Medical',
 'dentists': 'Health & Medical',
 'health': 'Health & Medical',
 'medcenters': 'Health & Medical',
 'opthamalogists': 'Health & Medical',
 'physicians': 'Health & Medical',
 'homeservices': 'Home Services',
 'landscaping': 'Home Services',
 'plumbing': 'Home Services',
 'realestateagents': 'Home Services',
 'realestatesvcs': 'Home Services',
 'tcm': 'Home Services',
 'utilities': 'Home Services',
 'airports': 'Hotels & Travel',
 'hotels': 'Hotels & Travel',
 'hotelstravel': 'Hotels & Travel',
 'tours': 'Hotels & Travel',
 'transport': 'Hotels & Travel',
 'travelservices': 'Hotels & Travel',
 'localflavor': 'Local Flavor',
 'funeralservices': 'Local Services',
 'itservices': 'Local Services',
 'junkremovalandhauling': 'Local Services',
 'laundryservices': 'Local Services',
 'localservices': 'Local Services',
 'nonprofit': 'Local Services',
 'massmedia': 'Mass Media',
 'bars': 'Nightlife',
 'nightlife': 'Nightlife',
 'adultentertainment': 'Nightlife',
 'pet_sitting': 'Pets',
 'pets': 'Pets',
 'petservices': 'Pets',
 'petstore': 'Pets',
 'estateplanning': 'Professional Services',
 'lawyers': 'Professional Services',
 'legalservices': 'Professional Services',
 'professional': 'Professional Services',
 'wholesalers': 'Professional Services',
 'publicservicesgovt': 'Public Services & Government',
 'religiousorgs': 'Religious Organizations',
 'african': 'Restaurants',
 'arabian': 'Restaurants',
 'belgian': 'Restaurants',
 'brazilian': 'Restaurants',
 'breakfast_brunch': 'Restaurants',
 'caribbean': 'Restaurants',
 'cafes': 'Restaurants',
 'chinese': 'Restaurants',
 'donburi': 'Restaurants',
 'french': 'Restaurants',
 'german': 'Restaurants',
 'italian': 'Restaurants',
 'japanese': 'Restaurants',
 'latin': 'Restaurants',
 'malaysian': 'Restaurants',
 'mediterranean': 'Restaurants',
 'mexican': 'Restaurants',
 'mideastern': 'Restaurants',
 'polish': 'Restaurants',
 'portuguese': 'Restaurants',
 'restaurants': 'Restaurants',
 'spanish': 'Restaurants',
 'turkish': 'Restaurants',
 'artsandcrafts': 'Shopping',
 'fashion': 'Shopping',
 'flowers': 'Shopping',
 'gardening': 'Shopping',
 'homeandgarden': 'Shopping',
 'kitchenandbath': 'Shopping',
 'media': 'Shopping',
 'musicinstrumentservices': 'Shopping',
 'opticians': 'Shopping',
 'shopping': 'Shopping',
 'sportgoods': 'Shopping',
 'sportswear': 'Shopping'}

# %%
top_150 = ['Restaurants',
 'Shopping',
 'Food',
 'Beauty & Spas',
 'Home Services',
 'Health & Medical',
 'Local Services',
 'Automotive',
 'Nightlife',
 'Bars',
 'Event Planning & Services',
 'Active Life',
 'Fashion',
 'Coffee & Tea',
 'Sandwiches',
 'Hair Salons',
 'Fast Food',
 'American (Traditional)',
 'Pizza',
 'Home & Garden',
 'Auto Repair',
 'Hotels & Travel',
 'Arts & Entertainment',
 'Professional Services',
 'Doctors',
 'Real Estate',
 'Burgers',
 'Breakfast & Brunch',
 'Nail Salons',
 'Fitness & Instruction',
 'Italian',
 'Mexican',
 'Specialty Food',
 'Chinese',
 'American (New)',
 'Pets',
 'Hair Removal',
 'Bakeries',
 'Dentists',
 'Grocery',
 'Skin Care',
 'Cafes',
 'Education',
 'Desserts',
 'Financial Services',
 'Contractors',
 "Women's Clothing",
 'Pet Services',
 'General Dentistry',
 'Massage',
 'Ice Cream & Frozen Yogurt',
 'Hotels',
 'Japanese',
 'Chicken Wings',
 'Day Spas',
 'Seafood',
 'Salad',
 'Apartments',
 'Waxing',
 'Gyms',
 'Caterers',
 'Tires',
 'Sushi Bars',
 'Flowers & Gifts',
 'Venues & Event Spaces',
 'Sports Bars',
 'Oil Change Stations',
 'Accessories',
 'Sporting Goods',
 'Pubs',
 'Cosmetics & Beauty Supply',
 'Cosmetic Dentists',
 'Hair Stylists',
 'Barbers',
 'Car Dealers',
 'Auto Parts & Supplies',
 'Home Decor',
 'Wine & Spirits',
 'Beer',
 'Trainers',
 'Delis',
 'Furniture Stores',
 'Canadian (New)',
 'Asian Fusion',
 'Mediterranean',
 'Convenience Stores',
 'Eyelash Service',
 "Men's Clothing",
 'Barbeque',
 'Massage Therapy',
 'Jewelry',
 'Arts & Crafts',
 'Drugstores',
 'Medical Centers',
 'Department Stores',
 'Juice Bars & Smoothies',
 'Steakhouses',
 'Heating & Air Conditioning/HVAC',
 'Electronics',
 'Lounges',
 'Pet Groomers',
 'IT Services & Computer Repair',
 'Real Estate Services',
 'Gas Stations',
 'Specialty Schools',
 'Indian',
 'Thai',
 'Dry Cleaning & Laundry',
 'Laundry Services',
 'Shoe Stores',
 'Diners',
 'Chiropractors',
 'Music & Video',
 'Mags',
 'Books',
 'Plumbing',
 'Party & Event Planning',
 'Public Services & Government',
 'Banks & Credit Unions',
 'Veterinarians',
 'Pet Sitting',
 'Optometrists',
 'Vietnamese',
 'Real Estate Agents',
 'Body Shops',
 'Home Cleaning',
 'Makeup Artists',
 'Mobile Phones',
 'Middle Eastern',
 'Medical Spas',
 'Yoga',
 'Landscaping',
 'Pet Stores',
 'Cocktail Bars',
 'Car Wash',
 'Wine Bars',
 'Eyewear & Opticians',
 'Printing Services',
 'Florists',
 'Movers',
 'Auto Detailing',
 'Greek',
 'Vegetarian',
 'Photographers',
 'Transportation',
 'Performing Arts',
 'Hair Extensions',
 'Lawyers',
 'French',
 'Self Storage',
 'Physical Therapy']

# %%
dict_1 = {'Active Life': ['active',
  'diving',
  'fitness',
  'gyms',
  'martialarts',
  'othersalons',
  'parks',
  'zoos'],
 'Arts & Entertainment': ['arts',
  'farms',
  'festivals',
  'movietheaters',
  'museums',
  'psychic_astrology',
  'social_clubs',
  'wineries'],
 'Automotive': ['auto', 'autoglass', 'autopartssupplies', 'autorepair'],
 'Beauty & Spas': ['beautysvc',
  'hair',
  'hairremoval',
  'medicalspa',
  'skincare',
  'tanning'],
 'Bicycles': ['bicycles'],
 'Education': ['artclasses',
  'education',
  'specialtyschools',
  'tastingclasses'],
 'Event Planning & Services': ['eventservices',
  'partyequipmentrentals',
  'photographers'],
 'Financial Services': ['financialservices', 'insurance'],
 'Food': ['breweries', 'food', 'gourmet', 'jpsweets'],
 'Health & Medical': ['c_and_mh',
  'cannabis_clinics',
  'crisispregnancycenters',
  'dentalhygienists',
  'diagnosticservices',
  'dentists',
  'health',
  'medcenters',
  'opthamalogists',
  'physicians'],
 'Home Services': ['homeservices',
  'landscaping',
  'plumbing',
  'realestateagents',
  'realestatesvcs',
  'tcm',
  'utilities'],
 'Hotels & Travel': ['airports',
  'hotels',
  'hotelstravel',
  'tours',
  'transport',
  'travelservices'],
 'Local Flavor': ['localflavor'],
 'Local Services': ['funeralservices',
  'itservices',
  'junkremovalandhauling',
  'laundryservices',
  'localservices',
  'nonprofit'],
 'Mass Media': ['massmedia'],
 'Nightlife': ['bars', 'nightlife', 'adultentertainment'],
 'Pets': ['pet_sitting', 'pets', 'petservices', 'petstore'],
 'Professional Services': ['estateplanning',
  'lawyers',
  'legalservices',
  'professional',
  'wholesalers'],
 'Public Services & Government': ['publicservicesgovt'],
 'Religious Organizations': ['religiousorgs'],
 'Restaurants': ['african',
  'arabian',
  'belgian',
  'brazilian',
  'breakfast_brunch',
  'caribbean',
  'cafes',
  'chinese',
  'donburi',
  'french',
  'german',
  'italian',
  'japanese',
  'latin',
  'malaysian',
  'mediterranean',
  'mexican',
  'mideastern',
  'polish',
  'portuguese',
  'restaurants',
  'spanish',
  'turkish'],
 'Shopping': ['artsandcrafts',
  'fashion',
  'flowers',
  'gardening',
  'homeandgarden',
  'kitchenandbath',
  'media',
  'musicinstrumentservices',
  'opticians',
  'shopping',
  'sportgoods',
  'sportswear']}

# %%
dict_2 = {'active': ['Airsoft',
  'Amateur Sports Teams',
  'Amusement Parks',
  'Aquariums',
  'Archery',
  'ATV Rentals/Tours',
  'Axe Throwing',
  'Badminton',
  'Baseball Fields',
  'Basketball Courts',
  'Bathing Area',
  'Batting Cages',
  'Beach Equipment Rentals',
  'Beaches',
  'Beach Volleyball',
  'Bicycle Paths',
  'Bike Parking',
  'Bike Rentals',
  'Boating',
  'Bobsledding',
  'Bocce Ball',
  'Bowling',
  'Bubble Soccer',
  'Bungee Jumping',
  'Canyoneering',
  'Carousels',
  'Challenge Courses',
  'Climbing',
  'Cycling Classes',
  'Dart Arenas',
  'Day Camps',
  'Disc Golf',
  'Diving',
  'Escape Games',
  'Experiences',
  'Fencing Clubs',
  'Fishing',
  'Fitness & Instruction',
  'Flyboarding',
  'Soccer',
  'Gliding',
  'Go Karts',
  'Golf',
  'Gun/Rifle Ranges',
  'Gymnastics',
  'Handball',
  'Hang Gliding',
  'Hiking',
  'Horseback Riding',
  'Horse Racing',
  'Hot Air Balloons',
  'Indoor Playcentre',
  'Jet Skis',
  'Kids Activities',
  'Kiteboarding',
  'Lakes',
  'Laser Tag',
  'Lawn Bowling',
  'Mini Golf',
  'Mountain Biking',
  'Nudist',
  'Paddleboarding',
  'Paintball',
  'Paragliding',
  'Parasailing',
  'Parks',
  'Pickleball',
  'Playgrounds',
  'Public Plazas',
  'Races & Competitions',
  'Racing Experience',
  'Rafting/Kayaking',
  'Recreation Centers',
  'Rock Climbing',
  'Sailing',
  'Scavenger Hunts',
  'Scooter Rentals',
  'Senior Centers',
  'Skating Rinks',
  'Skiing',
  'Skydiving',
  'Sledding',
  'Snorkeling',
  'Sport Equipment Hire',
  'Sports Clubs',
  'Squash',
  'Summer Camps',
  'Surfing',
  'Surf Lifesaving',
  'Swimming Pools',
  'Tennis',
  'Trampoline Parks',
  'Tubing',
  'Volleyball',
  'Water Parks',
  'Wildlife Hunting Ranges',
  'Ziplining',
  'Zoos',
  'Zorbing'],
 'adultentertainment': ['Strip Clubs', 'Striptease Dancers'],
 'african': ['Senegalese', 'South African'],
 'airports': ['Airport Terminals'],
 'arabian': ['Arab Pizza'],
 'artclasses': ['Glass Blowing'],
 'arts': ['Arcades',
  'Betting Centers',
  'Bingo Halls',
  'Cabaret',
  'Casinos',
  'Castles',
  'Choirs',
  'Country Clubs',
  'Cultural Center',
  'Eatertainment',
  'Farms',
  'Festivals',
  'Botanical Gardens',
  'Haunted Houses',
  'LAN Centers',
  'Mah Jong Halls',
  'Makerspaces',
  'Marching Bands',
  'Cinema',
  'Museums',
  'Observatories',
  'Opera & Ballet',
  'Pachinko',
  'Paint & Sip',
  'Planetarium',
  'Supernatural Readings',
  'Race Tracks',
  'Rodeo',
  'Social Clubs',
  'Sports Betting',
  'Professional Sports Teams',
  'Stadiums & Arenas',
  'Street Art',
  'Studio Taping',
  'Tablao Flamenco',
  'Performing Arts',
  'Ticket Sales',
  'Virtual Reality Centers'],
 'artsandcrafts': ['Art Supplies',
  'Ateliers',
  'Cooking Classes',
  'Costumes',
  'Embroidery & Crochet',
  'Fabric Stores',
  'Framing',
  'Paint-Your-Own Pottery',
  'Cards & Stationery'],
 'auto': ['Aircraft Dealers',
  'Aircraft Repairs',
  'Auto Detailing',
  'Auto Customization',
  'Car Inspectors',
  'Auto Electric Services',
  'Auto Glass Services',
  'Auto Loan Providers',
  'Auto Parts & Supplies',
  'Auto Repair',
  'Auto Security',
  'Auto Upholstery',
  'Aviation Services',
  'Boat Dealers',
  'Boat Parts & Supplies',
  'Body Shops',
  'Car Dealers',
  'Car Auctions',
  'Car Brokers',
  'Car Buyers',
  'Car Share Services',
  'Car Wash',
  'EV Charging Stations',
  'Fuel Docks',
  'Golf Cart Dealers',
  'Hybrid Car Repair',
  'Interlock Systems',
  'Marinas',
  'Mobile Dent Repair',
  'Mobility Equipment Sales & Services',
  'Motorsport Vehicle Dealers',
  'Motorcycle Dealers',
  'Motorcycle Repair',
  'Motorsport Vehicle Repairs',
  'Oil Change Stations',
  'Parking',
  'Registration Services',
  'Roadside Assistance',
  'RV Dealers',
  'RV Repair',
  'Service Stations',
  'Gas Stations',
  'Smog Check Stations',
  'Car Stereo Installation',
  'Tires',
  'Towing',
  'Trailer Dealers',
  'Trailer Rental',
  'Trailer Repair',
  'Transmission Repair',
  'Truck Rental',
  'Commercial Truck Dealers',
  'Commercial Truck Repair',
  'Used Car Dealers',
  'Vehicle Shipping',
  'Vehicle Wraps',
  'Wheel & Rim Repair',
  'Windshield Installation & Repair'],
 'autoglass': ['Car Window Tinting'],
 'autopartssupplies': ['Motorcycle Parts & Supplies'],
 'autorepair': ['DIY Auto Shop'],
 'bars': ['Absinthe Bars',
  'Airport Lounges',
  'Beach Bars',
  'Beer Bar',
  'Champagne Bars',
  'Cigar Bars',
  'Cocktail Bars',
  'Dive Bars',
  'Drive-Thru Bars',
  'Gay Bars',
  'Hookah Bars',
  'Hotel bar',
  'Irish Pub',
  'Lounges',
  'Pubs',
  'Pulquerias',
  'Sake Bars',
  'Speakeasies',
  'Sports Bars',
  'Tabac',
  'Tiki Bars',
  'Vermouth Bars',
  'Whiskey Bars',
  'Wine Bars'],
 'beautysvc': ['Acne Treatment',
  'Barbers',
  'Cosmetics & Beauty Supply',
  'Erotic Massage',
  'Eyebrow Services',
  'Eyelash Service',
  'Foot Care',
  'Hair Salons',
  'Hair Extensions',
  'Hair Loss Centers',
  'Hair Removal',
  'Hot Springs',
  'Makeup Artists',
  'Massage',
  'Medical Spas',
  'Nail Salons',
  'Perfume',
  'Permanent Makeup',
  'Piercing',
  'Skin Care',
  'Day Spas',
  'Tanning',
  'Tattoo',
  'Teeth Whitening'],
 'belgian': ['Flemish'],
 'bicycles': ['Bike Associations',
  'Bike Repair',
  'Bike Shop',
  'Special Bikes'],
 'brazilian': ['Brazilian Empanadas',
  'Central Brazilian',
  'Northeastern Brazilian',
  'Northern Brazilian',
  'Rodizios'],
 'breakfast_brunch': ['Pancakes'],
 'breweries': ['Brewpubs'],
 'c_and_mh': ['Psychoanalysts',
  'Psychologists',
  'Psychotherapists',
  'Sex Therapists',
  'Sophrologists',
  'Sports Psychologists'],
 'cafes': ['Themed Cafes'],
 'cannabis_clinics': ['Cannabis Tours'],
 'caribbean': ['Dominican', 'Haitian', 'Puerto Rican', 'Trinidadian'],
 'chinese': ['Cantonese',
  'Congee',
  'Dim Sum',
  'Fuzhou',
  'Hainan',
  'Hakka',
  'Henghwa',
  'Hokkien',
  'Hunan',
  'Pekinese',
  'Shanghainese',
  'Szechuan',
  'Teochew'],
 'crisispregnancycenters': ['Faith-based Crisis Pregnancy Centers'],
 'dentalhygienists': ['Storefront Clinics', 'Mobile Clinics'],
 'dentists': ['Cosmetic Dentists',
  'Endodontists',
  'General Dentistry',
  'Oral Surgeons',
  'Orthodontists',
  'Pediatric Dentists',
  'Periodontists'],
 'diagnosticservices': ['Diagnostic Imaging', 'Laboratory Testing'],
 'diving': ['Free Diving', 'Scuba Diving'],
 'donburi': ['Gyudon', 'Oyakodon'],
 'education': ['Adult Education',
  'Art Classes',
  'College Counseling',
  'Colleges & Universities',
  'Educational Services',
  'Elementary Schools',
  'Middle Schools & High Schools',
  'Montessori Schools',
  'Preschools',
  'Private Schools',
  'Private Tutors',
  'Religious Schools',
  'Special Education',
  'Specialty Schools',
  'Tasting Classes',
  'Test Preparation',
  'Tutoring Centers',
  'Waldorf Schools'],
 'estateplanning': ['Wills, Trusts, & Probates'],
 'eventservices': ['Balloon Services',
  'Bartenders',
  'Boat Charters',
  'Caricatures',
  'Caterers',
  'Clowns',
  'DJs',
  'Party & Event Planning',
  'Face Painting',
  'Floral Designers',
  'Game Truck Rental',
  'Golf Cart Rentals',
  'Henna Artists',
  'Magicians',
  'Mohels',
  'Musicians',
  'Officiants',
  'Party Bike Rentals',
  'Party Bus Rentals',
  'Party Characters',
  'Party Equipment Rentals',
  'Party Supplies',
  'Personal Chefs',
  'Photo Booth Rentals',
  'Photographers',
  'Silent Disco',
  'Sommelier Services',
  'Team Building Activities',
  'Trivia Hosts',
  'Valet Services',
  'Venues & Event Spaces',
  'Videographers',
  'Wedding Planning',
  'Wedding Chapels'],
 'farms': ['Attraction Farms', 'Pick Your Own Farms', 'Ranches'],
 'fashion': ['Accessories',
  'Ceremonial Clothing',
  "Children's Clothing",
  'Clothing Rental',
  'Formal Wear',
  'Fur Clothing',
  'Hats',
  'Kimonos',
  'Leather Goods',
  'Lingerie',
  'Maternity Wear',
  "Men's Clothing",
  'Plus Size Fashion',
  'Shoe Stores',
  'Sleepwear',
  'Stockings',
  'Surf Shop',
  'Swimwear',
  'Traditional Clothing',
  'Used, Vintage & Consignment',
  "Women's Clothing"],
 'festivals': ['Fun Fair',
  'General Festivals',
  'Trade Fairs',
  'Christmas Markets'],
 'financialservices': ['Banks & Credit Unions',
  'Business Financing',
  'Currency Exchange',
  'Debt Relief Services',
  'Financial Advising',
  'Installment Loans',
  'Insurance',
  'Investing',
  'Mortgage Lenders',
  'Check Cashing/Pay-day Loans',
  'Tax Services',
  'Title Loans'],
 'fitness': ['Aerial Fitness',
  'Barre Classes',
  'Boot Camps',
  'Boxing',
  'Cardio Classes',
  'Dance Studios',
  'EMS Training',
  'Golf Lessons',
  'Gyms',
  'Trainers',
  'Martial Arts',
  'Meditation Centers',
  'Pilates',
  'Qi Gong',
  'Self-defense Classes',
  'Swimming Lessons/Schools',
  'Tai Chi',
  'Yoga'],
 'flowers': ['Florists', 'Gift Shops'],
 'food': ['Acai Bowls',
  'Backshop',
  'Bagels',
  'Bakeries',
  'Beer, Wine & Spirits',
  'Bento',
  'Beverage Store',
  'Breweries',
  'Bubble Tea',
  'Butcher',
  'Patisserie/Cake Shop',
  'Chimney Cakes',
  'Churros',
  'Cideries',
  'Coffee & Tea',
  'Coffee Roasteries',
  'Coffee & Tea Supplies',
  'Convenience Stores',
  'CSA',
  'Cupcakes',
  'Custom Cakes',
  'Delicatessen',
  'Desserts',
  'Distilleries',
  'Do-It-Yourself Food',
  'Donairs',
  'Donuts',
  'Parent Cafes',
  'Empanadas',
  'Ethical Grocery',
  'Farmers Market',
  'Fishmonger',
  'Food Delivery Services',
  'Food Trucks',
  'Friterie',
  'Gelato',
  'Mulled Wine',
  'Specialty Food',
  'Grocery',
  'Hawker Centre',
  'Honey',
  'Ice Cream & Frozen Yogurt',
  'Imported Food',
  'Internet Cafes',
  'International Grocery',
  'Japanese Sweets',
  'Juice Bars & Smoothies',
  'Kiosk',
  'Kombucha',
  'Meaderies',
  'Milkshake Bars',
  'Nasi Lemak',
  'Organic Stores',
  'Panzerotti',
  'Piadina',
  'Poke',
  'Pretzels',
  'Salumerie',
  'Shaved Ice',
  'Shaved Snow',
  'Smokehouse',
  'Street Vendors',
  'Sugar Shacks',
  'Tea Rooms',
  'Torshi',
  'Tortillas',
  'Water Stores',
  'Wineries',
  'Zapiekanka'],
 'french': ['Alsatian',
  'Auvergnat',
  'Berrichon',
  'Bourguignon',
  'Mauritius',
  'Nicoise',
  'Provencal',
  'Reunion'],
 'funeralservices': ['Cremation Services', 'Mortuary Services'],
 'gardening': ['Hydroponics'],
 'german': ['Baden',
  'Eastern German',
  'Franconian',
  'Hessian',
  'Northern German',
  'Palatine',
  'Rhinelandian'],
 'gourmet': ['Candy Stores',
  'Cheese Shops',
  'Chocolatiers & Shops',
  'Dagashi',
  'Dried Fruit',
  'Frozen Food',
  'Health Markets',
  'Herbs & Spices',
  'Macarons',
  'Fruits & Veggies',
  'Meat Shops',
  'Olive Oil',
  'Pasta Shops',
  'Popcorn Shops',
  'Seafood Markets',
  'Tofu Shops'],
 'gyms': ['Circuit Training Gyms', 'Interval Training Gyms'],
 'hair': ['Blow Dry/Out Services',
  'Hair Stylists',
  'Kids Hair Salons',
  "Men's Hair Salons"],
 'hairremoval': ['Laser Hair Removal',
  'Sugaring',
  'Threading Services',
  'Waxing'],
 'health': ['Acupuncture',
  'Alternative Medicine',
  'Animal Assisted Therapy',
  'Assisted Living Facilities',
  'Ayurveda',
  'Behavior Analysts',
  'Blood & Plasma Donation Centers',
  'Body Contouring',
  'Counseling & Mental Health',
  'Cannabis Clinics',
  'Cannabis Collective',
  'Medical Cannabis Referrals',
  'Chiropractors',
  'Colonics',
  'Concierge Medicine',
  'Crisis Pregnancy Centers',
  'Cryotherapy',
  'Dental Hygienists',
  'Dentists',
  'Diagnostic Services',
  'Dialysis Clinics',
  'Dietitians',
  'Doulas',
  'Emergency Rooms',
  'Float Spa',
  'Habilitative Services',
  'Halfway Houses',
  'Halotherapy',
  'Health Coach',
  'Health Insurance Offices',
  'Hearing Aids',
  'Hearing Aid Providers',
  'Herbal Shops',
  'Home Health Care',
  'Hospice',
  'Hospitals',
  'Hydrotherapy',
  'Hypnosis/Hypnotherapy',
  'IV Hydration',
  'Lactation Services',
  'Laser Eye Surgery/Lasik',
  'Lice Services',
  'Massage Therapy',
  'Medical Centers',
  'Medical Foot Care',
  'Medical Transportation',
  'Memory Care',
  'Midwives',
  'Nurse Practitioner',
  'Nutritionists',
  'Occupational Therapy',
  'Optometrists',
  'Organ & Tissue Donor Services',
  'Orthotics',
  'Oxygen Bars',
  'Personal Care Services',
  'Pharmacy',
  'Physical Therapy',
  'Doctors',
  'Placenta Encapsulations',
  'Postpartum Care',
  'Prenatal/Perinatal Care',
  'Prosthetics',
  'Prosthodontists',
  'Psychotechnical Tests',
  'Reflexology',
  'Rehabilitation Center',
  'Reiki',
  'Reproductive Health Services',
  'Retirement Homes',
  'Saunas',
  'Skilled Nursing',
  'Sleep Specialists',
  'Speech Therapists',
  'Sperm Clinic',
  'Traditional Chinese Medicine',
  'Ultrasound Imaging Centers',
  'Urgent Care',
  'Weight Loss Centers'],
 'homeandgarden': ['Appliances',
  'Candle Stores',
  'Christmas Trees',
  'Furniture Stores',
  'Nurseries & Gardening',
  'Grilling Equipment',
  'Hardware Stores',
  'Holiday Decorations',
  'Home Decor',
  'Hot Tub & Pool',
  'Kitchen & Bath',
  'Lighting Stores',
  'Linens',
  'Materiale elettrico',
  'Mattresses',
  'Outdoor Furniture Stores',
  'Paint Stores',
  'Playsets',
  'Pumpkin Patches',
  'Rugs',
  'Sheds & Outdoor Storage',
  'Tableware'],
 'homeservices': ['Artificial Turf',
  'Shades & Blinds',
  'Building Supplies',
  'Cabinetry',
  'Carpenters',
  'Carpeting',
  'Carpet Installation',
  'Childproofing',
  'Chimney Sweeps',
  'Contractors',
  'Countertop Installation',
  'Damage Restoration',
  'Decks & Railing',
  'Demolition Services',
  'Door Sales/Installation',
  'Drywall Installation & Repair',
  'Electricians',
  'Excavation Services',
  'Fences & Gates',
  'Fireplace Services',
  'Fire Protection Services',
  'Firewood',
  'Flooring',
  'Foundation Repair',
  'Furniture Assembly',
  'Garage Door Services',
  'Gardeners',
  'Glass & Mirrors',
  'Grout Services',
  'Gutter Services',
  'Handyman',
  'Home Inspectors',
  'Home Organization',
  'Home Automation',
  'Home Cleaning',
  'Home Energy Auditors',
  'Home Network Installation',
  'Home Theatre Installation',
  'Home Window Tinting',
  'House Sitters',
  'Heating & Air Conditioning/HVAC',
  'Insulation Installation',
  'Interior Design',
  'Irrigation',
  'Landscape Architects',
  'Landscaping',
  'Lighting Fixtures & Equipment',
  'Keys & Locksmiths',
  'Masonry/Concrete',
  'Mobile Home Repair',
  'Movers',
  'Packing Services',
  'Painters',
  'Patio Coverings',
  'Plumbing',
  'Pool Cleaners',
  'Pool & Hot Tub Service',
  'Pressure Washers',
  'Real Estate',
  'Refinishing Services',
  'Roofing',
  'Roof Inspectors',
  'Sauna Installation & Repair',
  'Holiday Decorating Services',
  'Security Systems',
  'Shutters',
  'Solar Installation',
  'Solar Panel Cleaning',
  'Structural Engineers',
  'Stucco Services',
  'Television Service Providers',
  'Tiling',
  'Tree Services',
  'Utilities',
  'Siding',
  'Wallpapering',
  'Water Heater Installation/Repair',
  'Waterproofing',
  'Water Purification Services',
  'Windows Installation',
  'Window Washing'],
 'hotels': ['Agriturismi',
  'Mountain Huts',
  'Pensions',
  'Residences',
  'Rest Stops',
  'Ryokan'],
 'hotelstravel': ['Airports',
  'Bed & Breakfast',
  'Campgrounds',
  'Car Rental',
  'Guest Houses',
  'Health Retreats',
  'Hostels',
  'Hotels',
  'Motorcycle Rental',
  'Resorts',
  'RV Parks',
  'RV Rental',
  'Ski Resorts',
  'Tours',
  'Train Stations',
  'Transportation',
  'Travel Services',
  'Vacation Rentals',
  'Vacation Rental Agents'],
 'insurance': ['Auto Insurance', 'Home & Rental Insurance', 'Life Insurance'],
 'italian': ['Abruzzese',
  'Altoatesine',
  'Apulian',
  'Calabrian',
  'Cucina campana',
  'Emilian',
  'Friulan',
  'Ligurian',
  'Lumbard',
  'Napoletana',
  'Piemonte',
  'Roman',
  'Sardinian',
  'Sicilian',
  'Tuscan',
  'Venetian'],
 'itservices': ['Data Recovery', 'Mobile Phone Repair', 'Telecommunications'],
 'japanese': ['Blowfish',
  'Conveyor Belt Sushi',
  'Donburi',
  'Hand Rolls',
  'Horumon',
  'Izakaya',
  'Japanese Curry',
  'Kaiseki',
  'Kushikatsu',
  'Oden',
  'Okinawan',
  'Okonomiyaki',
  'Onigiri',
  'Ramen',
  'Robatayaki',
  'Soba',
  'Sukiyaki',
  'Takoyaki',
  'Tempura',
  'Teppanyaki',
  'Tonkatsu',
  'Udon',
  'Unagi',
  'Western Style Japanese Food',
  'Yakiniku',
  'Yakitori'],
 'jpsweets': ['Taiyaki'],
 'junkremovalandhauling': ['Dumpster Rental'],
 'kitchenandbath': ['Kitchen Supplies'],
 'landscaping': ['Lawn Services'],
 'latin': ['Colombian', 'Salvadoran', 'Venezuelan'],
 'laundryservices': ['Dry Cleaning', 'Laundromat'],
 'lawyers': ['Bankruptcy Law',
  'Business Law',
  'Consumer Law',
  'Contract Law',
  'Criminal Defense Law',
  'Disability Law',
  'Divorce & Family Law',
  'DUI Law',
  'Elder Law',
  'Employment Law',
  'Entertainment Law',
  'Estate Planning Law',
  'General Litigation',
  'Immigration Law',
  'IP & Internet Law',
  'Medical Law',
  'Personal Injury Law',
  'Real Estate Law',
  'Social Security Law',
  'Tax Law',
  'Traffic Ticketing Law',
  'Workers Compensation Law'],
 'legalservices': ['Court Reporters', 'Process Servers'],
 'localflavor': ['Parklets',
  'Public Art',
  'Unofficial Yelp Events',
  'Yelp Events'],
 'localservices': ['3D Printing',
  'Adoption Services',
  'Air Duct Cleaning',
  'Appraisal Services',
  'Art Installation',
  'Art Restoration',
  'Awnings',
  'Bail Bondsmen',
  'Bike Repair/Maintenance',
  'Biohazard Cleanup',
  'Bookbinding',
  'Bus Rental',
  'Calligraphy',
  'Carpet Cleaning',
  'Carpet Dyeing',
  'Child Care & Day Care',
  'Clock Repair',
  'Community Book Box',
  'Community Gardens',
  'Printing Services',
  'Couriers & Delivery Services',
  'Crane Services',
  'Donation Center',
  'Elder Care Planning',
  'Electronics Repair',
  'Elevator Services',
  'Engraving',
  'Environmental Abatement',
  'Environmental Testing',
  'Farm Equipment Repair',
  'Fingerprinting',
  'Forestry',
  'Funeral Services & Cemeteries',
  'Furniture Repair',
  'Generator Installation/Repair',
  'Gestorias',
  'Grill Services',
  'Gunsmith',
  'Hazardous Waste Disposal',
  'Appliances & Repair',
  'Hydro-jetting',
  'Ice Delivery',
  'Internet Booths & Calling Centers',
  'IT Services & Computer Repair',
  'Jewelry Repair',
  'Junk Removal & Hauling',
  'Junkyards',
  'Knife Sharpening',
  'Laundry Services',
  'Machine & Tool Rental',
  'Machine Shops',
  'Mailbox Centers',
  'Metal Detector Services',
  'Metal Fabricators',
  'Misting System Services',
  'Musical Instrument Services',
  'Nanny Services',
  'Community Service/Non-Profit',
  'Notaries',
  'Outdoor Power Equipment Services',
  'Pest Control',
  'Portable Toilet Services',
  'Powder Coating',
  'Propane',
  'Record Labels',
  'Recording & Rehearsal Studios',
  'Recycling Center',
  'Furniture Rental',
  'Furniture Reupholstery',
  'Sandblasting',
  'Screen Printing/T-Shirt Printing',
  'Screen Printing',
  'Self Storage',
  'Septic Services',
  'Sewing & Alterations',
  'Shipping Centers',
  'Shoe Repair',
  'Shoe Shine',
  'Smoking Areas',
  'Snow Removal',
  'Snuggle Services',
  'Stonemasons',
  'TV Mounting',
  'Watch Repair',
  'Water Delivery',
  'Well Drilling',
  'Wildlife Control',
  'Youth Club'],
 'malaysian': ['Mamak', 'Nyonya'],
 'martialarts': ['Brazilian Jiu-jitsu',
  'Chinese Martial Arts',
  'Karate',
  'Kickboxing',
  'Muay Thai',
  'Taekwondo'],
 'massmedia': ['Print Media', 'Radio Stations', 'Television Stations'],
 'medcenters': ['Bulk Billing', 'Osteopaths', 'Walk-in Clinics'],
 'media': ['Bookstores',
  'Comic Books',
  'Newspapers & Magazines',
  'Music & DVDs',
  'Videos & Video Game Rental',
  'Video Game Stores',
  'Vinyl Records'],
 'medicalspa': ['Aestheticians'],
 'mediterranean': ['Falafel'],
 'mexican': ['Eastern Mexican',
  'Jaliscan',
  'Northern Mexican',
  'Oaxacan',
  'Pueblan',
  'Tacos',
  'Tamales',
  'Yucatan'],
 'mideastern': ['Egyptian', 'Lebanese'],
 'movietheaters': ['Drive-In Theater', 'Outdoor Movies'],
 'museums': ['Art Museums', "Children's Museums"],
 'musicinstrumentservices': ['Guitar Stores',
  'Piano Services',
  'Piano Stores',
  'Vocal Coach'],
 'nightlife': ['Adult Entertainment',
  'Bar Crawl',
  'Bars',
  'Beer Gardens',
  'Club Crawl',
  'Coffeeshops',
  'Comedy Clubs',
  'Country Dance Halls',
  'Dance Clubs',
  'Dance Restaurants',
  'Fasil Music',
  'Jazz & Blues',
  'Karaoke',
  'Music Venues',
  'Piano Bars',
  'Pool Halls'],
 'nonprofit': ['Food Banks', 'Homeless Shelters'],
 'opthamalogists': ['Retina Specialists'],
 'opticians': ['Sunglasses'],
 'othersalons': ['Nail Technicians'],
 'parks': ['Dog Parks', 'Skate Parks'],
 'partyequipmentrentals': ['Audio/Visual Equipment Rental',
  'Bounce House Rentals',
  'Karaoke Rental'],
 'pet_sitting': ['Pet Boarding'],
 'pets': ['Animal Shelters',
  'Horse Boarding',
  'Pet Adoption',
  'Pet Services',
  'Pet Stores',
  'Veterinarians'],
 'petservices': ['Holistic Animal Care',
  'Animal Physical Therapy',
  'Aquarium Services',
  'Dog Walkers',
  'Emergency Pet Hospital',
  'Farriers',
  'Pet Groomers',
  'Pet Sitting',
  'Pet Training',
  'Pet Breeders',
  'Pet Cremation Services',
  'Pet Hospice',
  'Pet Insurance',
  'Pet Photography',
  'Pet Transportation',
  'Pet Waste Removal'],
 'petstore': ['Bird Shops', 'Local Fish Stores', 'Reptile Shops'],
 'photographers': ['Boudoir Photography',
  'Event Photography',
  'Session Photography'],
 'physicians': ['Addiction Medicine',
  'Allergists',
  'Anesthesiologists',
  'Audiologist',
  'Cardiologists',
  'Cosmetic Surgeons',
  'Dermatologists',
  'Ear Nose & Throat',
  'Emergency Medicine',
  'Endocrinologists',
  'Family Practice',
  'Fertility',
  'Gastroenterologist',
  'Geneticists',
  'Gerontologists',
  'Hepatologists',
  'Homeopathic',
  'Hospitalists',
  'Immunodermatologists',
  'Infectious Disease Specialists',
  'Internal Medicine',
  'Naturopathic/Holistic',
  'Nephrologists',
  'Neurologist',
  'Neuropathologists',
  'Neurotologists',
  'Obstetricians & Gynecologists',
  'Oncologist',
  'Ophthalmologists',
  'Orthopedists',
  'Osteopathic Physicians',
  'Otologists',
  'Pain Management',
  'Pathologists',
  'Pediatricians',
  'Phlebologists',
  'Plastic Surgeons',
  'Podiatrists',
  'Preventive Medicine',
  'Proctologists',
  'Psychiatrists',
  'Pulmonologist',
  'Radiologists',
  'Rheumatologists',
  'Spine Surgeons',
  'Sports Medicine',
  'Surgeons',
  'Tattoo Removal',
  'Toxicologists',
  'Tropical Medicine',
  'Undersea/Hyperbaric Medicine',
  'Urologists',
  'Vascular Medicine'],
 'plumbing': ['Backflow Services'],
 'polish': ['Pierogis'],
 'portuguese': ['Alentejo',
  'Algarve',
  'Azores',
  'Beira',
  'Fado Houses',
  'Madeira',
  'Minho',
  'Ribatejo',
  'Tras-os-Montes'],
 'professional': ['Accountants',
  'Advertising',
  'Architects',
  'Art Consultants',
  'Billing Services',
  'Boat Repair',
  'Bookkeepers',
  'Business Consulting',
  'Career Counseling',
  'Commissioned Artists',
  'Customs Brokers',
  'Digitizing Services',
  'Duplication Services',
  'Editorial Services',
  'Employment Agencies',
  'Feng Shui',
  'Graphic Design',
  'Indoor Landscaping',
  'Internet Service Providers',
  'Lawyers',
  'Legal Services',
  'Life Coach',
  'Marketing',
  'Matchmakers',
  'Mediators',
  'Music Production Services',
  'Office Cleaning',
  'Patent Law',
  'Payroll Services',
  'Personal Assistants',
  'Private Investigation',
  'Product Design',
  'Public Adjusters',
  'Public Relations',
  'Security Services',
  'Shredding Services',
  'Signmaking',
  'Software Development',
  'Talent Agencies',
  'Taxidermy',
  'Tenant and Eviction Law',
  'Translation Services',
  'Video/Film Production',
  'Web Design',
  'Wholesalers'],
 'psychic_astrology': ['Astrologers',
  'Mystics',
  'Psychic Mediums',
  'Psychics'],
 'publicservicesgovt': ['Authorized Postal Representative',
  'Civic Center',
  'Community Centers',
  'Courthouses',
  'Departments of Motor Vehicles',
  'Embassy',
  'Fire Departments',
  'Jails & Prisons',
  'Landmarks & Historical Buildings',
  'Libraries',
  'Municipality',
  'Police Departments',
  'Post Offices',
  'Registry Office',
  'Tax Office',
  'Town Hall'],
 'realestate': ['Apartments',
  'Art Space Rentals',
  'Commercial Real Estate',
  'Condominiums',
  'Estate Liquidation',
  'Home Developers',
  'Homeowner Association',
  'Home Staging',
  'Housing Cooperatives',
  'Kitchen Incubators',
  'Mobile Home Dealers',
  'Mobile Home Parks',
  'Mortgage Brokers',
  'Property Management',
  'Real Estate Agents',
  'Real Estate Services',
  'Shared Office Spaces',
  'University Housing'],
 'realestateagents': ['Apartment Agents'],
 'realestatesvcs': ['Real Estate Photography', 'Land Surveying'],
 'religiousorgs': ['Afro-Brazilian',
  'Buddhist Temples',
  'Churches',
  'Hindu Temples',
  'Mosques',
  'Shrines',
  'Sikh Temples',
  'Spiritism',
  'Synagogues',
  'Taoist Temples'],
 'restaurants': ['Afghan',
  'African',
  'Andalusian',
  'Arabian',
  'Argentine',
  'Armenian',
  'Asian Fusion',
  'Asturian',
  'Australian',
  'Austrian',
  'Baguettes',
  'Bangladeshi',
  'Basque',
  'Bavarian',
  'Barbeque',
  'Beer Garden',
  'Beer Hall',
  'Beisl',
  'Belgian',
  'Bistros',
  'Black Sea',
  'Brasseries',
  'Brazilian',
  'Breakfast & Brunch',
  'British',
  'Buffets',
  'Bulgarian',
  'Burgers',
  'Burmese',
  'Cafes',
  'Cafeteria',
  'Cajun/Creole',
  'Cambodian',
  'Canteen',
  'Caribbean',
  'Catalan',
  'Cheesesteaks',
  'Chicken Wings',
  'Chicken Shop',
  'Chilean',
  'Chinese',
  'Comfort Food',
  'Corsican',
  'Creperies',
  'Cuban',
  'Curry Sausage',
  'Cypriot',
  'Czech',
  'Czech/Slovakian',
  'Danish',
  'Delis',
  'Diners',
  'Dinner Theater',
  'Dumplings',
  'Eastern European',
  'Eritrean',
  'Ethiopian',
  'Filipino',
  'Fischbroetchen',
  'Fish & Chips',
  'Flatbread',
  'Fondue',
  'Food Court',
  'Food Stands',
  'Freiduria',
  'French',
  'Galician',
  'Game Meat',
  'Gastropubs',
  'Georgian',
  'German',
  'Giblets',
  'Gluten-Free',
  'Greek',
  'Guamanian',
  'Halal',
  'Hawaiian',
  'Heuriger',
  'Himalayan/Nepalese',
  'Hong Kong Style Cafe',
  'Honduran',
  'Hot Dogs',
  'Fast Food',
  'Hot Pot',
  'Hungarian',
  'Iberian',
  'Indonesian',
  'Indian',
  'International',
  'Irish',
  'Island Pub',
  'Israeli',
  'Italian',
  'Japanese',
  'Jewish',
  'Kebab',
  'Kopitiam',
  'Korean',
  'Kosher',
  'Kurdish',
  'Laos',
  'Laotian',
  'Latin American',
  'Lyonnais',
  'Malaysian',
  'Meatballs',
  'Mediterranean',
  'Mexican',
  'Middle Eastern',
  'Milk Bars',
  'Modern Australian',
  'Modern European',
  'Mongolian',
  'Moroccan',
  'American (New)',
  'Canadian (New)',
  'New Mexican Cuisine',
  'New Zealand',
  'Nicaraguan',
  'Night Food',
  'Nikkei',
  'Noodles',
  'Norcinerie',
  'Traditional Norwegian',
  'Open Sandwiches',
  'Oriental',
  'Pakistani',
  'Pan Asian',
  'Parma',
  'Persian/Iranian',
  'Peruvian',
  'PF/Comercial',
  'Pita',
  'Pizza',
  'Polish',
  'Polynesian',
  'Pop-Up Restaurants',
  'Portuguese',
  'Potatoes',
  'Poutineries',
  'Pub Food',
  'Live/Raw Food',
  'Rice',
  'Romanian',
  'Rotisserie Chicken',
  'Russian',
  'Salad',
  'Sandwiches',
  'Scandinavian',
  'Schnitzel',
  'Scottish',
  'Seafood',
  'Serbo Croatian',
  'Signature Cuisine',
  'Singaporean',
  'Slovakian',
  'Somali',
  'Soul Food',
  'Soup',
  'Southern',
  'Spanish',
  'Sri Lankan',
  'Steakhouses',
  'French Southwest',
  'Supper Clubs',
  'Sushi Bars',
  'Swabian',
  'Swedish',
  'Swiss Food',
  'Syrian',
  'Tabernas',
  'Taiwanese',
  'Tapas Bars',
  'Tapas/Small Plates',
  'Tavola Calda',
  'Tex-Mex',
  'Thai',
  'American (Traditional)',
  'Traditional Swedish',
  'Trattorie',
  'Turkish',
  'Ukrainian',
  'Uzbek',
  'Vegan',
  'Vegetarian',
  'Venison',
  'Vietnamese',
  'Waffles',
  'Wok',
  'Wraps',
  'Yugoslav'],
 'shopping': ['Adult',
  'Antiques',
  'Arts & Crafts',
  'Auction Houses',
  'Baby Gear & Furniture',
  'Battery Stores',
  'Bespoke Clothing',
  'Brewing Supplies',
  'Bridal',
  'Cannabis Dispensaries',
  'Mobile Phone Accessories',
  'Chinese Bazaar',
  'Computers',
  'Concept Shops',
  'Customized Merchandise',
  'Department Stores',
  'Diamond Buyers',
  'Discount Store',
  'Drones',
  'Drugstores',
  'Duty-Free Shops',
  'Electronics',
  'Farming Equipment',
  'Fashion',
  'Fireworks',
  'Fitness/Exercise Equipment',
  'Flea Markets',
  'Flowers & Gifts',
  'Art Galleries',
  'Gemstones & Minerals',
  'Gold Buyers',
  'Guns & Ammo',
  'Head Shops',
  'High Fidelity Audio Equipment',
  'Hobby Shops',
  'Home & Garden',
  'Horse Equipment Shops',
  'Jewelry',
  'Knitting Supplies',
  'Livestock Feed & Supply',
  'Luggage',
  'Market Stalls',
  'Books, Mags, Music & Video',
  'Medical Supplies',
  'Military Surplus',
  'Mobile Phones',
  'Motorcycle Gear',
  'Musical Instruments & Teachers',
  'Office Equipment',
  'Eyewear & Opticians',
  'Outlet Stores',
  'Packing Supplies',
  'Pawn Shops',
  'Personal Shopping',
  'Photography Stores & Services',
  'Pool & Billiards',
  'Pop-up Shops',
  'Props',
  'Public Markets',
  'Religious Items',
  'Safe Stores',
  'Safety Equipment',
  'Scandinavian Design',
  'Shopping Centers',
  'Shopping Passages',
  'Souvenir Shops',
  'Spiritual Shop',
  'Sporting Goods',
  'Tabletop Games',
  'Teacher Supplies',
  'Thrift Stores',
  'Tickets',
  'Tobacco Shops',
  'Toy Stores',
  'Trophy Shops',
  'Uniforms',
  'Used Bookstore',
  'Vape Shops',
  'Vitamins & Supplements',
  'Watches',
  'Wholesale Stores',
  'Wigs'],
 'skincare': ['Estheticians'],
 'social_clubs': ['Veterans Organizations'],
 'spanish': ['Arroceria / Paella'],
 'specialtyschools': ['Art Schools',
  'Bartending Schools',
  'Cheerleading',
  'Childbirth Education',
  'Circus Schools',
  'Cooking Schools',
  'Cosmetology Schools',
  'CPR Classes',
  'Dance Schools',
  'Drama Schools',
  'Driving Schools',
  'DUI Schools',
  'Firearm Training',
  'First Aid Classes',
  'Flight Instruction',
  'Food Safety Training',
  'Language Schools',
  'Massage Schools',
  'Nursing Schools',
  'Parenting Classes',
  'Photography Classes',
  'Pole Dancing Classes',
  'Samba Schools',
  'Ski Schools',
  'Speech Training',
  'Surf Schools',
  'Traffic Schools',
  'Vocational & Technical School'],
 'sportgoods': ['Bikes',
  'Dive Shops',
  'Golf Equipment',
  'Hockey Equipment',
  'Hunting & Fishing Supplies',
  'Outdoor Gear',
  'Skate Shops',
  'Ski & Snowboard Shops',
  'Sports Wear'],
 'sportswear': ['Dance Wear'],
 'tanning': ['Spray Tanning', 'Tanning Beds'],
 'tastingclasses': ['Cheese Tasting Classes', 'Wine Tasting Classes'],
 'tcm': ['Tui Na'],
 'tours': ['Aerial Tours',
  'Architectural Tours',
  'Art Tours',
  'Beer Tours',
  'Bike tours',
  'Boat Tours',
  'Bus Tours',
  'Food Tours',
  'Historical Tours',
  'Scooter Tours',
  'Walking Tours',
  'Whale Watching Tours',
  'Wine Tours'],
 'transport': ['Airlines',
  'Airport Shuttles',
  'Bike Sharing',
  'Buses',
  'Bus Stations',
  'Cable Cars',
  'Dolmus Station',
  'Ferries',
  'Limos',
  'Metro Stations',
  'Pedicabs',
  'Private Jet Charter',
  'Public Transportation',
  'Shared Taxis',
  'Taxis',
  'Town Car Service',
  'Trains',
  'Water Taxis'],
 'travelservices': ['Luggage Storage',
  'Passport & Visa Services',
  'Travel Agents',
  'Visitor Centers'],
 'turkish': ['Chee Kufta',
  'Gozleme',
  'Homemade Food',
  'Lahmacun',
  'Ottoman Cuisine',
  'Turkish Ravioli'],
 'utilities': ['Electricity Suppliers',
  'Natural Gas Suppliers',
  'Water Suppliers'],
 'wholesalers': ['Restaurant Supplies'],
 'wineries': ['Wine Tasting Room'],
 'zoos': ['Petting Zoos']}
